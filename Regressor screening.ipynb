# %% [markdown]
# ## Screeening regressors for wine dataset (from Kaggle)
# **LazyRegressor**\
# Dataset: https://www.kaggle.com/uciml/red-wine-quality-cortez-et-al-2009

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time 
from sklearn.model_selection import train_test_split

# %%
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ### Read the csv file

# %%
dfwine = pd.read_csv ('winequality-red.csv')

# %% [markdown]
# ### Data preprocessing

# %%
dfwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.40              0.70         0.00            1.90       0.08
# 1              7.80              0.88         0.00            2.60       0.10
# 2              7.80              0.76         0.04            2.30       0.09
# 3             11.20              0.28         0.56            1.90       0.07
# 4              7.40              0.70         0.00            1.90       0.08
# ...             ...               ...          ...             ...        ...
# 1594           6.20              0.60         0.08            2.00       0.09
# 1595           5.90              0.55         0.10            2.20       0.06
# 1596           6.30              0.51         0.13            2.30       0.08
# 1597           5.90              0.65         0.12            2.00       0.07
# 1598           6.00              0.31         0.47            3.60       0.07
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                   11.00                 34.00     1.00 3.51       0.56
# 1                   25.00                 67.00     1.00 3.20       0.68
# 2                   15.00                 54.00     1.00 3.26       0.65
# 3                   17.00                 60.00     1.00 3.16       0.58
# 4                   11.00                 34.00     1.00 3.51       0.56
# ...                   ...                   ...      ...  ...        ...
# 1594                32.00                 44.00     0.99 3.45       0.58
# 1595                39.00                 51.00     1.00 3.52       0.76
# 1596                29.00                 40.00     1.00 3.42       0.75
# 1597                32.00                 44.00     1.00 3.57       0.71
# 1598                18.00                 42.00     1.00 3.39       0.66
#
#       alcohol  quality
# 0        9.40        5
# 1        9.80        5
# 2        9.80        5
# 3        9.80        6
# 4        9.40        5
# ...       ...      ...
# 1594    10.50        5
# 1595    11.20        6
# 1596    11.00        6
# 1597    10.20        5
# 1598    11.00        6
#
# [1599 rows x 12 columns]

# %%
#checking data integrity
dfwine.isna().count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
data= dfwine
X=dfwine.drop('quality', axis=1)
Y=dfwine['quality']

# %%
#Splitting data for training and testing. 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=45)

# %% [markdown]
# ### Comparing Regressors

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=False,  custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
# Out:
# 100%|██████████| 42/42 [00:06<00:00,  6.17it/s]

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=False,  custom_metric=None)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:06<00:00,  6.82it/s]

# %%
# Performance table of the training set 
predictions_train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# DecisionTreeRegressor                        1.00       1.00  0.00        0.02
# ExtraTreeRegressor                           1.00       1.00  0.00        0.02
# ExtraTreesRegressor                          1.00       1.00  0.00        0.32
# GaussianProcessRegressor                     1.00       1.00  0.00        0.27
# XGBRegressor                                 1.00       1.00  0.05        0.17
# RandomForestRegressor                        0.93       0.93  0.21        0.59
# LGBMRegressor                                0.92       0.92  0.23        0.14
# HistGradientBoostingRegressor                0.92       0.92  0.23        1.43
# BaggingRegressor                             0.90       0.90  0.25        0.09
# GradientBoostingRegressor                    0.64       0.65  0.48        0.25
# SVR                                          0.54       0.55  0.54        0.10
# KNeighborsRegressor                          0.54       0.54  0.55        0.08
# NuSVR                                        0.51       0.52  0.56        0.11
# AdaBoostRegressor                            0.46       0.47  0.59        0.18
# MLPRegressor                                 0.42       0.42  0.61        1.97
# LinearRegression                             0.36       0.36  0.64        0.04
# TransformedTargetRegressor                   0.36       0.36  0.64        0.01
# Lars                                         0.36       0.36  0.64        0.02
# Ridge                                        0.36       0.36  0.64        0.01
# RidgeCV                                      0.36       0.36  0.64        0.01
# BayesianRidge                                0.36       0.36  0.64        0.23
# LassoLarsIC                                  0.36       0.36  0.64        0.01
# LassoCV                                      0.36       0.36  0.64        0.09
# ElasticNetCV                                 0.36       0.36  0.64        0.09
# LassoLarsCV                                  0.36       0.36  0.64        0.03
# LarsCV                                       0.36       0.36  0.64        0.03
# SGDRegressor                                 0.35       0.36  0.64        0.01
# HuberRegressor                               0.35       0.36  0.64        0.05
# PoissonRegressor                             0.35       0.36  0.64        0.02
# OrthogonalMatchingPursuitCV                  0.35       0.35  0.65        0.03
# LinearSVR                                    0.35       0.35  0.65        0.05
# TweedieRegressor                             0.30       0.30  0.67        0.02
# GeneralizedLinearRegressor                   0.30       0.30  0.67        0.02
# GammaRegressor                               0.30       0.30  0.67        0.03
# OrthogonalMatchingPursuit                    0.23       0.24  0.70        0.01
# RANSACRegressor                              0.16       0.17  0.74        0.10
# ElasticNet                                  -0.01       0.00  0.81        0.02
# DummyRegressor                              -0.01       0.00  0.81        0.01
# Lasso                                       -0.01       0.00  0.81        0.01
# LassoLars                                   -0.01       0.00  0.81        0.01
# PassiveAggressiveRegressor                  -0.09      -0.08  0.84        0.01
# KernelRidge                                -49.06     -48.63  5.68        0.08

# %%
# Performance table of the test set 
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# RandomForestRegressor                        0.47       0.49  0.58        0.62
# ExtraTreesRegressor                          0.47       0.49  0.58        0.32
# XGBRegressor                                 0.44       0.46  0.60        0.15
# HistGradientBoostingRegressor                0.43       0.45  0.61        1.29
# LGBMRegressor                                0.42       0.44  0.61        0.13
# BaggingRegressor                             0.41       0.43  0.61        0.07
# GradientBoostingRegressor                    0.40       0.42  0.62        0.23
# AdaBoostRegressor                            0.38       0.40  0.63        0.19
# NuSVR                                        0.38       0.40  0.63        0.09
# SVR                                          0.37       0.40  0.63        0.10
# SGDRegressor                                 0.32       0.34  0.66        0.01
# BayesianRidge                                0.31       0.34  0.66        0.01
# ElasticNetCV                                 0.31       0.34  0.66        0.09
# RidgeCV                                      0.31       0.34  0.66        0.01
# LarsCV                                       0.31       0.34  0.66        0.03
# LassoLarsCV                                  0.31       0.34  0.66        0.03
# LassoCV                                      0.31       0.34  0.66        0.08
# Ridge                                        0.31       0.34  0.66        0.01
# Lars                                         0.31       0.34  0.66        0.01
# TransformedTargetRegressor                   0.31       0.34  0.66        0.01
# LinearRegression                             0.31       0.34  0.66        0.01
# LassoLarsIC                                  0.31       0.34  0.66        0.01
# PoissonRegressor                             0.31       0.33  0.67        0.02
# OrthogonalMatchingPursuitCV                  0.30       0.32  0.67        0.02
# HuberRegressor                               0.29       0.32  0.67        0.05
# KNeighborsRegressor                          0.28       0.30  0.68        0.04
# LinearSVR                                    0.27       0.30  0.68        0.02
# TweedieRegressor                             0.27       0.30  0.68        0.01
# GeneralizedLinearRegressor                   0.27       0.30  0.68        0.01
# GammaRegressor                               0.27       0.29  0.68        0.02
# OrthogonalMatchingPursuit                    0.14       0.17  0.74        0.01
# MLPRegressor                                 0.08       0.12  0.76        2.03
# DecisionTreeRegressor                       -0.02       0.01  0.81        0.02
# LassoLars                                   -0.04      -0.00  0.81        0.01
# DummyRegressor                              -0.04      -0.00  0.81        0.02
# Lasso                                       -0.04      -0.00  0.81        0.01
# ElasticNet                                  -0.04      -0.00  0.81        0.01
# RANSACRegressor                             -0.06      -0.03  0.82        0.09
# PassiveAggressiveRegressor                  -0.12      -0.08  0.85        0.01
# ExtraTreeRegressor                          -0.15      -0.11  0.86        0.01
# GaussianProcessRegressor                    -3.11      -2.97  1.62        0.15
# KernelRidge                                -48.56     -46.85  5.62        0.07

# %% [markdown]
# ### Random Forest Regressor
# with adjusted number of trees

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
clf = RandomForestRegressor(n_estimators=1500)
clf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(n_estimators=1500)

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# *RMSE*

# %%
mean_squared_error(Y_test, y_pred)
# Out:
# 0.34662401527777775

# %% [markdown]
# *R- squeared*

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred)
# Out:
# 0.47552604816412847
